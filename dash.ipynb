# %% [markdown]
# <a href="https://colab.research.google.com/github/eumiguelvieira09/cgeanalise/blob/main/dash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##CRIAÇÃO DE DASH
#Instalação das bibliotecas

#!pip install pandas
#!pip install numpy
#!pip install dash
#!pip install plotly


import pandas as pd
import numpy as np
import plotly.express as px

# %%
contrato = pd.read_csv("/content/drive/MyDrive/PROJETO_ANALISE_CGE/contrato_utf_.csv", sep=",",decimal=".",encoding="utf-8")
contrato.head()

# %%
import pandas as pd


# Extrair as 10000 primeiras linhas
df_novo = contrato.iloc[:10000]

# Salvar o novo dataset
df_novo.to_csv('/content/drive/MyDrive/PROJETO_ANALISE_CGE/df_novo.csv', index=False)  # Substitua pelo caminho onde deseja salvar o novo dataset

# %%
df_novo.head()

# %%
df_novo_minimo = contrato.iloc[:1000]
#df_novo_minimo.to_csv('/content/drive/MyDrive/PROJETO_ANALISE_CGE/df_novo_minimo.csv', index=False)

# %%
df_novo_minimo.describe

# %%
import plotly.graph_objs as go
import plotly.express as px
import pandas as pd

# Exemplo de DataFrame
#data = {
#    'Year': [2015, 2016, 2017, 2018, 2019],
#    'Sales': [100, 150, 200, 250, 300],
#    'Expenses': [50, 70, 90, 110, 130]
#}
df = pd.DataFrame(df_novo)

# Criar gráfico de linha para as vendas
fig_sales = px.bar(df, x='Tipo_Aquisicao', y='Valor_Empenhado', title='Vendas ao longo do tempo')

# Criar gráfico de barras para as despesas
fig_expenses = px.bar(df, x='Unidade', y='Valor_Empenhado', title='Despesas ao longo do tempo')

# Visualizar os gráficos em um dashboard
fig_sales.show()
fig_expenses.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px

# Carregar o dataset
df = df_novo  # Substitua pelo caminho do seu dataset

# Inicializar o aplicativo Dash
app = dash.Dash(__name__)

# Layout do aplicativo
app.layout = html.Div([
    html.H1("Dashboard Interativo"),

    # Dropdowns para escolher variáveis para os gráficos
    html.Label("Gráfico 1"),
    dcc.Dropdown(
        id='graph1-variable',
        options=[{'label': col, 'value': col} for col in df.columns],
        value=df.columns[0]  # valor padrão
    ),

    html.Label("Gráfico 2"),
    dcc.Dropdown(
        id='graph2-variable',
        options=[{'label': col, 'value': col} for col in df.columns],
        value=df.columns[1]  # valor padrão
    ),

    html.Label("Gráfico 3"),
    dcc.Dropdown(
        id='graph3-variable',
        options=[{'label': col, 'value': col} for col in df.columns],
        value=df.columns[2]  # valor padrão
    ),

    html.Label("Gráfico 4"),
    dcc.Dropdown(
        id='graph4-variable',
        options=[{'label': col, 'value': col} for col in df.columns],
        value=df.columns[3]  # valor padrão
    ),

    html.Label("Gráfico 5"),
    dcc.Dropdown(
        id='graph5-variable',
        options=[{'label': col, 'value': col} for col in df.columns],
        value=df.columns[4]  # valor padrão
    ),

    html.Label("Gráfico 6"),
    dcc.Dropdown(
        id='graph6-variable',
        options=[{'label': col, 'value': col} for col in df.columns],
        value=df.columns[5]  # valor padrão
    ),

    # Gráficos
    dcc.Graph(id='graph1'),
    dcc.Graph(id='graph2'),
    dcc.Graph(id='graph3'),
    dcc.Graph(id='graph4'),
    dcc.Graph(id='graph5'),
    dcc.Graph(id='graph6')
])

# Callbacks para atualizar os gráficos com base nas seleções dos dropdowns
@app.callback(
    Output('graph1', 'figure'),
    [Input('graph1-variable', 'value')]
)
def update_graph1(selected_variable):
    fig = px.histogram(df, x=selected_variable, title='Gráfico 1')
    return fig

@app.callback(
    Output('graph2', 'figure'),
    [Input('graph2-variable', 'value')]
)
def update_graph2(selected_variable):
    fig = px.histogram(df, x=selected_variable, title='Gráfico 2')
    return fig

@app.callback(
    Output('graph3', 'figure'),
    [Input('graph3-variable', 'value')]
)
def update_graph3(selected_variable):
    fig = px.histogram(df, x=selected_variable, title='Gráfico 3')
    return fig

@app.callback(
    Output('graph4', 'figure'),
    [Input('graph4-variable', 'value')]
)
def update_graph4(selected_variable):
    fig = px.histogram(df, x=selected_variable, title='Gráfico 4')
    return fig

@app.callback(
    Output('graph5', 'figure'),
    [Input('graph5-variable', 'value')]
)
def update_graph5(selected_variable):
    fig = px.histogram(df, x=selected_variable, title='Gráfico 5')
    return fig

@app.callback(
    Output('graph6', 'figure'),
    [Input('graph6-variable', 'value')]
)
def update_graph6(selected_variable):
    fig = px.histogram(df, x=selected_variable, title='Gráfico 6')
    return fig

# Rodar o aplicativo
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px

# Inicializar o aplicativo Dash
app = dash.Dash(__name__)

# Layout do aplicativo
app.layout = html.Div([
    html.H1("Dashboard Interativo"),

    # Dropdowns para escolher variáveis para os gráficos
    html.Label("Gráfico 1"),
    dcc.Dropdown(
        id='graph1-variable1',
        options=[{'label': col, 'value': col} for col in df_novo_minimo.columns],
        value=df_novo_minimo.columns[0]  # valor padrão
    ),
    dcc.Dropdown(
        id='graph1-variable2',
        options=[{'label': col, 'value': col} for col in df_novo_minimo.columns],
        value=df_novo_minimo.columns[1],  # valor padrão
        multi=True
    ),

    html.Label("Tipo de Gráfico 1"),
    dcc.Dropdown(
        id='graph1-type',
        options=[
            {'label': 'Histograma', 'value': 'histogram'},
            {'label': 'Dispersão', 'value': 'scatter'},
            {'label': 'Linha', 'value': 'line'},
            {'label': 'Barras', 'value': 'bar'},
            {'label': 'Pizza', 'value': 'pie'}
        ],
        value='histogram'
    ),

    html.Label("Gráfico 2"),
    dcc.Dropdown(
        id='graph2-variable1',
        options=[{'label': col, 'value': col} for col in df_novo_minimo.columns],
        value=df_novo_minimo.columns[2]  # valor padrão
    ),
    dcc.Dropdown(
        id='graph2-variable2',
        options=[{'label': col, 'value': col} for col in df_novo_minimo.columns],
        value=df_novo_minimo.columns[3],  # valor padrão
        multi=True
    ),

    html.Label("Tipo de Gráfico 2"),
    dcc.Dropdown(
        id='graph2-type',
        options=[
            {'label': 'Histograma', 'value': 'histogram'},
            {'label': 'Dispersão', 'value': 'scatter'},
            {'label': 'Linha', 'value': 'line'},
            {'label': 'Barras', 'value': 'bar'},
            {'label': 'Pizza', 'value': 'pie'}
        ],
        value='scatter'
    ),

    # Adicionar dropdowns e tipos de gráficos para os gráficos 3, 4, 5 e 6
    html.Label("Gráfico 3"),
    dcc.Dropdown(
        id='graph3-variable1',
        options=[{'label': col, 'value': col} for col in df_novo_minimo.columns],
        value=df_novo_minimo.columns[4]  # valor padrão
    ),
    dcc.Dropdown(
        id='graph3-variable2',
        options=[{'label': col, 'value': col} for col in df_novo_minimo.columns],
        value=df_novo_minimo.columns[5],  # valor padrão
        multi=True
    ),

    html.Label("Tipo de Gráfico 3"),
    dcc.Dropdown(
        id='graph3-type',
        options=[
            {'label': 'Histograma', 'value': 'histogram'},
            {'label': 'Dispersão', 'value': 'scatter'},
            {'label': 'Linha', 'value': 'line'},
            {'label': 'Barras', 'value': 'bar'},
            {'label': 'Pizza', 'value': 'pie'}
        ],
        value='line'
    ),

    html.Label("Gráfico 4"),
    dcc.Dropdown(
        id='graph4-variable1',
        options=[{'label': col, 'value': col} for col in df_novo_minimo.columns],
        value=df_novo_minimo.columns[6]  # valor padrão
    ),
    dcc.Dropdown(
        id='graph4-variable2',
        options=[{'label': col, 'value': col} for col in df_novo_minimo.columns],
        value=df_novo_minimo.columns[7],  # valor padrão
        multi=True
    ),

    html.Label("Tipo de Gráfico 4"),
    dcc.Dropdown(
        id='graph4-type',
        options=[
            {'label': 'Histograma', 'value': 'histogram'},
            {'label': 'Dispersão', 'value': 'scatter'},
            {'label': 'Linha', 'value': 'line'},
            {'label': 'Barras', 'value': 'bar'},
            {'label': 'Pizza', 'value': 'pie'}
        ],
        value='bar'
    ),

    html.Label("Gráfico 5"),
    dcc.Dropdown(
        id='graph5-variable1',
        options=[{'label': col, 'value': col} for col in df_novo_minimo.columns],
        value=df_novo_minimo.columns[8]  # valor padrão
    ),
    dcc.Dropdown(
        id='graph5-variable2',
        options=[{'label': col, 'value': col} for col in df_novo_minimo.columns],
        value=df_novo_minimo.columns[9],  # valor padrão
        multi=True
    ),

    html.Label("Tipo de Gráfico 5"),
    dcc.Dropdown(
        id='graph5-type',
        options=[
            {'label': 'Histograma', 'value': 'histogram'},
            {'label': 'Dispersão', 'value': 'scatter'},
            {'label': 'Linha', 'value': 'line'},
            {'label': 'Barras', 'value': 'bar'},
            {'label': 'Pizza', 'value': 'pie'}
        ],
        value='pie'
    ),

    html.Label("Gráfico 6"),
    dcc.Dropdown(
        id='graph6-variable1',
        options=[{'label': col, 'value': col} for col in df_novo_minimo.columns],
        value=df_novo_minimo.columns[10]  # valor padrão
    ),
    dcc.Dropdown(
        id='graph6-variable2',
        options=[{'label': col, 'value': col} for col in df_novo_minimo.columns],
        value=df_novo_minimo.columns[11],  # valor padrão
        multi=True
    ),

    html.Label("Tipo de Gráfico 6"),
    dcc.Dropdown(
        id='graph6-type',
        options=[
            {'label': 'Histograma', 'value': 'histogram'},
            {'label': 'Dispersão', 'value': 'scatter'},
            {'label': 'Linha', 'value': 'line'},
            {'label': 'Barras', 'value': 'bar'},
            {'label': 'Pizza', 'value': 'pie'}
        ],
        value='histogram'
    ),

    # Gráficos
    dcc.Graph(id='graph1'),
    dcc.Graph(id='graph2'),
    dcc.Graph(id='graph3'),
    dcc.Graph(id='graph4'),
    dcc.Graph(id='graph5'),
    dcc.Graph(id='graph6')
])

# Callbacks para atualizar os gráficos com base nas seleções dos dropdowns
@app.callback(
    Output('graph1', 'figure'),
    [Input('graph1-variable1', 'value'),
     Input('graph1-variable2', 'value'),
     Input('graph1-type', 'value')]
)
def update_graph1(selected_variable1, selected_variable2, graph_type):
    if graph_type == 'histogram':
        fig = px.histogram(df_novo_minimo, x=selected_variable1, color=selected_variable2, title='Gráfico 1')
    elif graph_type == 'scatter':
        fig = px.scatter(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 1')
    elif graph_type == 'line':
        fig = px.line(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 1')
    elif graph_type == 'bar':
        fig = px.bar(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 1')
    elif graph_type == 'pie':
        fig = px.pie(df_novo_minimo, values=selected_variable1, names=selected_variable2, title='Gráfico 1')
    return fig

@app.callback(
    Output('graph2', 'figure'),
    [Input('graph2-variable1', 'value'),
     Input('graph2-variable2', 'value'),
     Input('graph2-type', 'value')]
)
def update_graph2(selected_variable1, selected_variable2, graph_type):
    if graph_type == 'histogram':
        fig = px.histogram(df_novo_minimo, x=selected_variable1, color=selected_variable2, title='Gráfico 2')
    elif graph_type == 'scatter':
        fig = px.scatter(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 2')
    elif graph_type == 'line':
        fig = px.line(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 2')
    elif graph_type == 'bar':
        fig = px.bar(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 2')
    elif graph_type == 'pie':
        fig = px.pie(df_novo_minimo, values=selected_variable1, names=selected_variable2, title='Gráfico 2')
    return fig

# Adicionar mais callbacks para os gráficos 3, 4, 5 e 6

@app.callback(
    Output('graph3', 'figure'),
    [Input('graph3-variable1', 'value'),
     Input('graph3-variable2', 'value'),
     Input('graph3-type', 'value')]
)
def update_graph3(selected_variable1, selected_variable2, graph_type):
    if graph_type == 'histogram':
        fig = px.histogram(df_novo_minimo, x=selected_variable1, color=selected_variable2, title='Gráfico 3')
    elif graph_type == 'scatter':
        fig = px.scatter(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 3')
    elif graph_type == 'line':
        fig = px.line(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 3')
    elif graph_type == 'bar':
        fig = px.bar(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 3')
    elif graph_type == 'pie':
        fig = px.pie(df_novo_minimo, values=selected_variable1, names=selected_variable2, title='Gráfico 3')
    return fig

@app.callback(
    Output('graph4', 'figure'),
    [Input('graph4-variable1', 'value'),
     Input('graph4-variable2', 'value'),
     Input('graph4-type', 'value')]
)
def update_graph4(selected_variable1, selected_variable2, graph_type):
    if graph_type == 'histogram':
        fig = px.histogram(df_novo_minimo, x=selected_variable1, color=selected_variable2, title='Gráfico 4')
    elif graph_type == 'scatter':
        fig = px.scatter(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 4')
    elif graph_type == 'line':
        fig = px.line(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 4')
    elif graph_type == 'bar':
        fig = px.bar(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 4')
    elif graph_type == 'pie':
        fig = px.pie(df_novo_minimo, values=selected_variable1, names=selected_variable2, title='Gráfico 4')
    return fig

@app.callback(
    Output('graph5', 'figure'),
    [Input('graph5-variable1', 'value'),
     Input('graph5-variable2', 'value'),
     Input('graph5-type', 'value')]
)
def update_graph5(selected_variable1, selected_variable2, graph_type):
    if graph_type == 'histogram':
        fig = px.histogram(df_novo_minimo, x=selected_variable1, color=selected_variable2, title='Gráfico 5')
    elif graph_type == 'scatter':
        fig = px.scatter(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 5')
    elif graph_type == 'line':
        fig = px.line(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 5')
    elif graph_type == 'bar':
        fig = px.bar(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 5')
    elif graph_type == 'pie':
        fig = px.pie(df_novo_minimo, values=selected_variable1, names=selected_variable2, title='Gráfico 5')
    return fig

@app.callback(
    Output('graph6', 'figure'),
    [Input('graph6-variable1', 'value'),
     Input('graph6-variable2', 'value'),
     Input('graph6-type', 'value')]
)
def update_graph6(selected_variable1, selected_variable2, graph_type):
    if graph_type == 'histogram':
        fig = px.histogram(df_novo_minimo, x=selected_variable1, color=selected_variable2, title='Gráfico 6')
    elif graph_type == 'scatter':
        fig = px.scatter(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 6')
    elif graph_type == 'line':
        fig = px.line(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 6')
    elif graph_type == 'bar':
        fig = px.bar(df_novo_minimo, x=selected_variable1, y=selected_variable2, title='Gráfico 6')
    elif graph_type == 'pie':
        fig = px.pie(df_novo_minimo, values=selected_variable1, names=selected_variable2, title='Gráfico 6')
    return fig

# Rodar o aplicativo
if __name__ == '__main__':
    app.run_server(debug=True)
